# %%
'''
problem 5

Setup your development environment with Python and Jupyter notebooks.  Show python and jupyter versions with the following commands:
import jupyter_core
import sys
print(jupyter_core.__version__)
print(sys.version)

'''
import jupyter_core
import sys
print(jupyter_core.__version__)
print(sys.version)
# Out:
# 5.7.2
# 3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:15:57) [MSC v.1916 64 bit (AMD64)]

# %%
'''
problem 6
Create a string of your choosing.  Create a second String from the first that converts all letters to caps.
'''
hello = "Hello world"
hello_upper = hello.upper()
print(hello_upper)
# Out:
# HELLO WORLD

# %%
'''
problem 7
Accept input and store in a float variable.
Do not worry about error checking at this point.
Print that variable with the sentence: "This is my float variable" and include 5 decimals in the formatting.
Test it.
'''
float_variable = float(input("enter a number with 5 decimal places: "))
print(f"This is my float variable {float_variable: .5f}")
# Out:
# enter a number with 5 decimal places:  0.12345
# This is my float variable  0.12345

# %%
'''
problem 8
Create a list of these integers = 4,4,35,357,76,3,4,3,3,2345,0,-54,2.
Sort the integers and print the list.
Add a comment in your code that explains if a list is a mutable or immutable type.
Next, enter code that would not affect the original and reverse sorts the integers (in a new list).  Test it.
(do not forget to comment your code)

'''
list_of_integers = [4,4,35,357,76,3,4,3,3,2345,0,-54,2]
list_of_integers.sort()
print(list_of_integers)

#Lists are mutable variable types in python.

#reverse order
list_of_integers_reverse = list_of_integers[::-1]
print(list_of_integers_reverse)
# Out:
# [-54, 0, 2, 3, 3, 3, 4, 4, 4, 35, 76, 357, 2345]
# [2345, 357, 76, 35, 4, 4, 4, 3, 3, 3, 2, 0, -54]
